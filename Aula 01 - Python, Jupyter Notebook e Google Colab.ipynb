# %% [markdown]
# # Exercício 1

# %% [markdown]
# ## Verificando a versão do Python

# %%
# !python -v
# Out:
# import _frozen_importlib # frozen
# import _imp # builtin
# import '_thread' # <class '_frozen_importlib.BuiltinImporter'>
# import '_warnings' # <class '_frozen_importlib.BuiltinImporter'>
# import '_weakref' # <class '_frozen_importlib.BuiltinImporter'>
# import '_io' # <class '_frozen_importlib.BuiltinImporter'>
# import 'marshal' # <class '_frozen_importlib.BuiltinImporter'>
# import 'posix' # <class '_frozen_importlib.BuiltinImporter'>
# import '_frozen_importlib_external' # <class '_frozen_importlib.FrozenImporter'>
# # installing zipimport hook
# import 'time' # <class '_frozen_importlib.BuiltinImporter'>
# import 'zipimport' # <class '_frozen_importlib.FrozenImporter'>
# # installed zipimport hook
# # /usr/lib/python3.12/encodings/__pycache__/__init__.cpython-312.pyc matches /usr/lib/python3.12/encodings/__init__.py
# # code object from '/usr/lib/python3.12/encodings/__pycache__/__init__.cpython-312.pyc'
# import '_codecs' # <class '_frozen_importlib.BuiltinImporter'>
# ...

# %% [markdown]
# ## 3. For loop

# %%
for counter in range(5):
  print(counter)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 4. Crie um dicionário de frutas

# %%
example_dict = {'apple': 5, 'oranges': 8, 'bananas': 13}

example_dict['oranges']
example_dict.keys()
example_dict.values()
example_dict.items()
# Out:
# dict_items([('apple', 5), ('oranges', 8), ('bananas', 13)])

# %% [markdown]
# ## 5. Converta o dicionário em lista

# %%
dict_to_list = list(example_dict.items())
dict_to_list
# Out:
# [('apple', 5), ('oranges', 8), ('bananas', 13)]

# %% [markdown]
# ## 6. Combinar mais um valor na lista `dict_to_list`

# %%
dict_to_list = dict_to_list + [('grapes', 15)]
dict_to_list
# Out:
# [('apple', 5), ('oranges', 8), ('bananas', 13), ('grapes', 15)]

# %% [markdown]
# ## 7. Ordene a lista de frutas em ordem alfabética

# %%
sorted(dict_to_list)
# Out:
# [('apple', 5), ('bananas', 13), ('grapes', 15), ('oranges', 8)]

# %%
dict_to_list
# Out:
# [('apple', 5), ('oranges', 8), ('bananas', 13), ('grapes', 15)]
